# %% [markdown]
# The actual build out process for ecoregion items is going to be somewhat involved. I've initiated a process to get a new [bot user account](https://www.wikidata.org/wiki/User:BristolBot) approved for running bot-based processes and submitted an [approval request](https://www.wikidata.org/wiki/Wikidata:Requests_for_permissions/Bot/BristolBot). I've submitted proposals for new external identifiers to handle the simple ID scheme for each of the 5 classification systems represented in the EPA ecoregion data.
#
# Identifier management seems like kind of a mess in Wikidata right now. There are hundreds of properties used as different kinds of internal and external identifiers. There's a nice overall schema that can be used in describing identifiers, and there's really no reason that we shouldn't have as many different kinds of identifier schemes as needed in the system, especially if they are well described, configured, referenced, and qualified. However, the process of establishing a new identifier is completely community based, and speed of getting something done is going to be inherently dependent on just how active a few individual people are. It would be nice to have some kind of generic identifier property that could be qualified with its own property value settings so that, in a case like mine of building out a whole new concept pool from source data, we could at least put identifiers where they belong. In the meantime, I worked with aliases/alternative labels as the only reasonable place to shove ID strings, and this seems to be in use elsewhere as well.
#
# I looked at the code for pywikibot, which is kind of the Swiss army knife tool for all things Mediawiki. After struggling with finding working examples of Wikidata processing, I went with the [wikidataintegrator](https://github.com/SuLab/WikidataIntegrator) from SuLab (Scripps). I forked it and started a [branch](https://github.com/skybristol/WikidataIntegrator/tree/ecoregion_helper) to build out what I needed for this case. I also got added to the SuLab's Slack channel on this as it seems like some interesting work going on there to jump in on.
#
# The wikidataintegrator has taken an interesting approach of building out "wdi_helpers" that seem to be dealing with specific kinds of business logic needed for individual collections of items and their Wikidata layout and requirements. I'm not sure it's the best approach to tie everything together into the one codebase as it seems like it might be better to externalize the specific cases and have a clean foundation that does the background work in a configurable way. However, the two use cases built out by the SuLab authors were pretty useful in helping me to understand the usage pattern, and I added a new one for the [ecoregion use case](https://github.com/skybristol/WikidataIntegrator/blob/ecoregion_helper/wikidataintegrator/wdi_helpers/ecoregion.py).
#
# The main thing that I had to adjust from what the SuLab folks have done is a different way of handling the "foreign keys" that I'm coming into the system with from source data. In my prep work, I generated what I called a "contextual identifier" that is essentially a uri stub that includes the specific classification system and the original source ID together in a urn-like string (e.g., US_L4CODE:51g). Where the SuLab work on documenting genomics data all seems to involve cases where they are able to use established identifier properties, I had to add a new function for working with aliases/alt-labels in Wikidata and stand this in place of their methods for identifying whether or not an item already exists in Wikidata to control create/update operations. I did try to mostly mimic the constructs they came up with so as not to monkey around in the code too much.
#
# I've successfully tested this process a few times to build out items (e.g., [Door Peninsula L4 Ecoregion](https://www.wikidata.org/wiki/Q98687985)). While I could probably get away with running the full set of items into the system, I'm holding off for a few days to see if someone gets around to my bot task and identifier property requests. I'm curious to figure out the level of activation energy needed in this community. The following code sequence grabs up my prepped ecoregion data (that's really where all the work went on), splits out items with existing identifiers, and creates a new item from source. It took a little bit of work to get here, but I'm pleased so far with the progress. Being able to build minimally on the wikidataintegrator work was a huge boost.

# %%
import pickle
from wikidataintegrator import wdi_core, wdi_login, wdi_helpers
import os

# %%
infile = open("data_cache/ecoregions.pkl", "rb")
ecoregions = pickle.load(infile)

# %%
ecoregions_in_wikidata = [i for i in ecoregions if i["wikidata_id"] is not None]
ecoregions_to_create = [i for i in ecoregions if i["wikidata_id"] is None]

# %%
login_instance = wdi_login.WDLogin(
    user=os.environ["WD_BOT"], 
    pwd=os.environ["WD_PASS"]
)

# %%
ecoregion = ecoregions_to_create[2]
display(ecoregion)
# Out:
# {'contextual_identifier': 'NA_L3CODE:9.4.5',
#  'wikidata_id': None,
#  'source': 'NA_CEC_Eco_Level3',
#  'common_name': 'Cross Timbers',
#  'part_of_identifiers': ['NA_L1CODE:9', 'NA_L2CODE:9.4'],
#  'x': -97.5065596504837,
#  'y': 33.5884848315732,
#  'admin_intersects': ['Q484603',
#   'Q484586',
#   'Q495867',
#   'Q495873',
#   'Q110500',
#   'Q495925',
#   'Q495951',
#   'Q379540',
#   'Q484596',
#   'Q112149',
#   'Q111844',
#   'Q486651',
#   'Q491616',
#   'Q108827',
#   'Q484616',
#   'Q495570',
#   'Q110384',
#   'Q111368',
#   'Q485024',
#   'Q110412',
#   'Q114550',
#   'Q489471',
#   'Q108784',
#   'Q489312',
#   'Q489457',
#   'Q156270',
#   'Q495479',
#   'Q108424',
#   'Q495930',
#   'Q495880',
#   'Q109457',
#   'Q109308',
#   'Q485042',
#   'Q491590',
#   'Q495581',
#   'Q489306',
#   'Q495906',
#   'Q495885',
#   'Q497854',
#   'Q109170',
#   'Q495899',
#   'Q485038',
#   'Q112673',
#   'Q485912',
#   'Q108793',
#   'Q495891',
#   'Q484567',
#   'Q110779',
#   'Q484590',
#   'Q1649',
#   'Q109265',
#   'Q156613',
#   'Q1439',
#   'Q375008',
#   'Q113843',
#   'Q374256',
#   'Q113919',
#   'Q109631',
#   'Q109825',
#   'Q490727',
#   'Q489486',
#   'Q109785',
#   'Q376546',
#   'Q156463',
#   'Q484574',
#   'Q486614',
#   'Q489477',
#   'Q495856',
#   'Q108952',
#   'Q114529',
#   'Q490690',
#   'Q495862',
#   'Q111316',
#   'Q374547',
#   'Q109636',
#   'Q112686',
#   'Q489327',
#   'Q1558',
#   'Q484600',
#   'Q376446',
#   'Q489481',
#   'Q108428',
#   'Q111168'],
#  'country_intersects': ['Q30']}

# %%
r = wdi_helpers.Ecoregion(
    identifier=ecoregion["contextual_identifier"],
    title=ecoregion["common_name"],
    instance_of=ecoregion["source"],
    country=["Q30"],
    located_in=ecoregion["admin_intersects"],
    latitude=ecoregion['y'],
    longitude=ecoregion['x']
)

# %%
wd_item = r.get_or_create(login=login_instance)
print(wd_item)
# Out:
# Q98688136

# %%
created_item = wdi_core.WDItemEngine(wd_item_id=wd_item)
created_item.get_wd_json_representation()
# Out:
# {'labels': {'en': {'language': 'en', 'value': 'Cross Timbers'}},
#  'descriptions': {'en': {'language': 'en',
#    'value': 'an instance of Level III ecoregion'}},
#  'claims': {'P131': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484603,
#        'id': 'Q484603'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$61397D49-5648-4B13-B1CF-12EB893D12FE'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484586,
#        'id': 'Q484586'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$8DCCC587-6F26-42BB-97DD-598ED39AB22A'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495867,
#        'id': 'Q495867'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$78076D5E-DEF2-4607-97F6-16BB64065B69'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495873,
#        'id': 'Q495873'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$647898F4-5102-4AAE-89FD-8F832F24BD20'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 110500,
#        'id': 'Q110500'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$C8902A12-78A6-4A9C-9B86-899CE2BD0450'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495925,
#        'id': 'Q495925'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$57356378-143D-4530-8675-85ECA8495B83'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495951,
#        'id': 'Q495951'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$6F7E2A1D-366A-432E-89A8-B0F05F55BA97'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 379540,
#        'id': 'Q379540'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$CD5AD76F-4B2F-4D01-8571-5E0098188143'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484596,
#        'id': 'Q484596'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$2CBD6113-193F-4FD7-B677-C76E5B3E4847'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 112149,
#        'id': 'Q112149'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A53DED34-6486-4BE6-973C-B2F9B82DEC7D'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 111844,
#        'id': 'Q111844'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$098783FD-DC3E-4CA5-9016-758DA409ABFB'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 486651,
#        'id': 'Q486651'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$B826841C-65F8-473E-BBED-C3D63494756F'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 491616,
#        'id': 'Q491616'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$C9EFA04F-C578-4666-AED7-9C1787A123E0'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108827,
#        'id': 'Q108827'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$FB957C2E-0802-471A-8E60-EE766563735B'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484616,
#        'id': 'Q484616'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$DCC279B0-6DA1-4249-9B56-D401D0E41E4F'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495570,
#        'id': 'Q495570'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1451060C-E438-4128-A806-368F3F110D52'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 110384,
#        'id': 'Q110384'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1581B2FF-BA54-4876-89EA-579F1D829919'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 111368,
#        'id': 'Q111368'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$7F5AB213-20FD-4F5F-AB28-616FB38CE65E'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 485024,
#        'id': 'Q485024'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$98FF55DC-81E0-45C7-B4DD-88A70BBD2062'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 110412,
#        'id': 'Q110412'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F30E292A-9AEF-47D9-9F43-2D0615EFDD00'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 114550,
#        'id': 'Q114550'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$158DE1C6-3C22-4130-B773-93A0F69CE768'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489471,
#        'id': 'Q489471'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$7B6AAB38-EBF3-47FE-9F91-06570165E653'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108784,
#        'id': 'Q108784'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$D2099BD5-B1EE-4CB4-9519-5EF68E511784'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489312,
#        'id': 'Q489312'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$CFE4A203-82EC-4793-A1DB-D59219088A9E'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489457,
#        'id': 'Q489457'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$446B4540-861F-4934-83AF-74B2D806F5A7'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 156270,
#        'id': 'Q156270'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$C3BD412D-BBA0-4358-8D30-8CDCC62C1DF3'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495479,
#        'id': 'Q495479'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$365CF2AB-3D3F-48D1-8518-71EA317101A7'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108424,
#        'id': 'Q108424'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$32D29C37-0645-4902-A4DE-2AC931BEF19E'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495930,
#        'id': 'Q495930'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$8C440E8D-591C-4A15-A884-0E450BD78860'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495880,
#        'id': 'Q495880'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$4AA3F77E-4677-4D97-8292-38C8AA595EC2'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109457,
#        'id': 'Q109457'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$AE83AED7-BC80-418F-8D7E-EB7C79BF55D5'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109308,
#        'id': 'Q109308'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1C25A454-FE97-4704-A2CC-E74F1A770886'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 485042,
#        'id': 'Q485042'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$30E606A4-2925-44E7-AF57-AA6FA685BE60'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 491590,
#        'id': 'Q491590'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$907E2303-4E92-490B-97EF-AE6B146599F1'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495581,
#        'id': 'Q495581'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$369071C1-A3FA-4E57-A6BA-F486CB5E5F04'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489306,
#        'id': 'Q489306'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F8427722-ACC0-4E1F-BF0A-53C5337F20E6'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495906,
#        'id': 'Q495906'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$90794DC5-787D-4425-9C6C-9BF0C52D2156'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495885,
#        'id': 'Q495885'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$0DE2B214-94F6-4EBE-8A7B-048F5478C9F3'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 497854,
#        'id': 'Q497854'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$3C2BA07D-4139-450D-B264-85EC9B7DA446'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109170,
#        'id': 'Q109170'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$FE73F9CD-3C5A-4B7A-9D49-CE2FE79B894C'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495899,
#        'id': 'Q495899'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$E84B4ED1-CDDC-4A9C-A7F0-4183EE2D00EC'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 485038,
#        'id': 'Q485038'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$31F57817-249E-48F6-89DE-BC5386CE8E6B'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 112673,
#        'id': 'Q112673'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F70926F2-1355-45DC-8ECD-8D4804307117'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 485912,
#        'id': 'Q485912'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$0E55398F-3066-40B8-AFC4-CC0B3090EE8F'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108793,
#        'id': 'Q108793'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$58004DD5-CA4A-46D6-83FD-B13DBFD50773'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495891,
#        'id': 'Q495891'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$E5EB94F5-BE0A-4AA8-8648-92A1AC9A1D56'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484567,
#        'id': 'Q484567'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A5536705-E827-416D-9F5F-017C56D68011'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 110779,
#        'id': 'Q110779'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A794922D-6572-4B6F-9E27-61F20C85A785'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484590,
#        'id': 'Q484590'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$D40A3967-2F77-40AE-9D14-05C99EA361F8'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1649,
#        'id': 'Q1649'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$3FF53793-859C-4B8B-800E-A09521D23FEC'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109265,
#        'id': 'Q109265'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$88541D1F-A902-4FFA-BC3F-994B442ACBF1'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 156613,
#        'id': 'Q156613'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$584556A7-D09E-4A9B-935A-EBEA68A6FCA2'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1439,
#        'id': 'Q1439'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F12A5C1B-7709-4D3D-846C-3D2006019C0C'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 375008,
#        'id': 'Q375008'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1176098E-5313-4B6F-B979-72E63C28924A'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 113843,
#        'id': 'Q113843'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$2281A7AB-24BC-4AB0-B6ED-A81793C3A3FA'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 374256,
#        'id': 'Q374256'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F28732D9-6D38-4A6D-94E4-F72C6A2BBAF9'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 113919,
#        'id': 'Q113919'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$95671609-5285-4021-843E-528B0724106B'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109631,
#        'id': 'Q109631'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$6424FDF3-9CF0-433C-A444-2C40BA644578'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109825,
#        'id': 'Q109825'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$7CE483AF-497A-4A30-BCF9-33BB082A7F86'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 490727,
#        'id': 'Q490727'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$E6849267-6228-4964-8295-A9CED8EE952B'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489486,
#        'id': 'Q489486'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A2972E7C-046C-420D-9126-56867FD2BFE2'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109785,
#        'id': 'Q109785'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$7BB559B1-BAEF-4453-8380-C28DB334089F'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 376546,
#        'id': 'Q376546'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1A739C54-AEEC-45E9-88E5-1728A1BCB96B'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 156463,
#        'id': 'Q156463'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$EC8E2E8D-FA83-4301-9165-D168CD17A127'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484574,
#        'id': 'Q484574'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$5FAA511D-0A00-4A2A-97F0-CF692E2EAE3F'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 486614,
#        'id': 'Q486614'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$06411F23-E86D-4CE5-90EB-F661BA28E49A'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489477,
#        'id': 'Q489477'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F1DBE915-AAED-47AC-9AD5-A6B99D37B291'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495856,
#        'id': 'Q495856'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$3D364BD0-509A-4025-BD28-A6F1E6A28C4E'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108952,
#        'id': 'Q108952'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$3ABA9DA8-BAE3-4A68-9415-F02C6DFBD752'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 114529,
#        'id': 'Q114529'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$E34D7745-C9D2-43D0-8A74-C98FE13B09F3'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 490690,
#        'id': 'Q490690'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$1672AB53-CF3D-4054-BBB8-0634CE1F2C2D'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 495862,
#        'id': 'Q495862'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$6636F408-CFFF-42AB-9AA2-EABCD387EF79'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 111316,
#        'id': 'Q111316'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$0BC2AAD0-DDD4-43CC-897E-9A4905B427A2'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 374547,
#        'id': 'Q374547'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F98E29B0-DE83-469D-82C7-041590C8AFFE'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 109636,
#        'id': 'Q109636'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$F4802BCB-C1F0-4928-BEF1-9AAFA147B0AA'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 112686,
#        'id': 'Q112686'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$374DDEA9-38D8-4946-A175-FA025E6EB9D9'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489327,
#        'id': 'Q489327'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$6AD59812-62A0-4E1E-BB49-BF456175BA24'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1558,
#        'id': 'Q1558'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A31BFCA4-8E62-4AA8-BEF3-B61DA934ED77'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 484600,
#        'id': 'Q484600'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$724E56B3-6651-4BF5-AAF2-EE62B5F2E189'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 376446,
#        'id': 'Q376446'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$2CE1CCAD-6633-400E-BE37-A7B03EB5D12E'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 489481,
#        'id': 'Q489481'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$291AF2D8-2F78-4A50-9029-686187F2B9E6'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 108428,
#        'id': 'Q108428'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$EFD2EF2A-EB88-4257-81B6-F24359E75066'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P131',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 111168,
#        'id': 'Q111168'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$A0D1BD48-7E99-4D1B-BD27-D2D7E8F6FE11'}],
#   'P17': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P17',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 30,
#        'id': 'Q30'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$C6421C7E-3714-46AC-B9CC-684A74264A35'}],
#   'P31': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P31',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 52111338,
#        'id': 'Q52111338'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$99724820-7818-4CF9-B4F4-E2ABF1B19100'}],
#   'P625': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P625',
#      'datavalue': {'value': {'latitude': 33.5884848315732,
#        'longitude': -97.5065596504837,
#        'precision': 4.25,
#        'globe': 'http://www.wikidata.org/entity/Q2'},
#       'type': 'globecoordinate'},
#      'datatype': 'globe-coordinate'},
#     'type': 'statement',
#     'rank': 'normal',
#     'qualifiers': {},
#     'qualifiers-order': [],
#     'references': [],
#     'id': 'Q98688136$6FC03AB3-042D-429A-9B8E-AD1B3941E15C'}]},
#  'aliases': {'en': [{'language': 'en', 'value': 'NA_L3CODE:9.4.5'}]},
#  'sitelinks': {}}
